# %% [markdown]
# <a href="https://colab.research.google.com/github/mubarak-pj/advance-python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
c=int(input("enter the third number:"))
if a>b and a>c:
  print("a is greater")
elif b>a and b>c:
  print("b is greater")
else:
  print("c is greater")
# Out:
# enter the first number:12
# enter the second number:54
# enter the third number:1
# b is greater

# %%
f=int(input("enter the number 100 to 800 :"))
d=f%3
e=f%7
if d==0:
  print(f"the number divisible by 3")
elif e==0:
  print(f"the number is divisible by 7")
else:
  print(f"the number is not divisible by 3 and 7")
# Out:
# enter the number 100 to 800 :120
# the number divisible by 3

# %%
f=int(input("enter the number 1 to 1000 :"))
d=f%8
if d==0:
  print(f"the number divisible by 8")
else:
  print(f"the number is not divisible by 8")
# Out:
# enter the number 1 to 1000 :180
# the number is not divisible by 8

# %%
for i in range(1, 6):
  print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(1,15):
  if (i%2==0):
    print(f"the number of {i} even")
  else:
    print(f"the number of {i} odd")
# Out:
# the number of 1 odd
# the number of 2 even
# the number of 3 odd
# the number of 4 even
# the number of 5 odd
# the number of 6 even
# the number of 7 odd
# the number of 8 even
# the number of 9 odd
# the number of 10 even
# the number of 11 odd
# the number of 12 even
# the number of 13 odd
# the number of 14 even

# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
sum=a+b
print(sum)
for i in a:
  fac=i
# Out:
# enter the first number:12
# enter the second number:24
# 36

# %%
a= int(input("Enter a number: "))
fac = 1
for i in range(1, a+ 1):
    fac = fac * i
print(f"The factorial of {a} is {fac}")
# Out:
# Enter a number: 1
# The factorial of 1 is 1

# %%
a = input("Enter a word: ")
if a == a[::-1]:
    print(f"{a} is a palindrome")
else:
    print(f"{a} is not a palindrome")
# Out:
# Enter a word: mom
# mom is a palindrome

# %%
#key function_name(parameters):
  #statement
  #reurn expresion

# %%
def mul(num):
  print(num*2)
mul(29)
# Out:
# 58

# %%
mul(2)
# Out:
# 4

# %%
def gift(name,gift):
  print(f"the name is {name} to given gift is {gift}")
gift("ram","bike")
# Out:
# the name is ram to given gift is bike

# %%
def gift(name,gift):
  print(f"the name is {name} to given gift is {gift}")

# %%
gift(name="sottumanny",gift="phone")
# Out:
# the name is sottumanny to given gift is phone

# %%
def gift(name,gift="car"):
  print(f"the name is {name} to given gift is {gift}")

# %%
gift("akku")
# Out:
# the name is akku to given gift is car

# %% [markdown]
# types of arb
